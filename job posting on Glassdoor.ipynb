# %% [markdown]
# # Data Science job posting on Glassdoor
# ##     Data cleaning and Transformation
#
# ### Questions to answer
# ##### * Can you make the salary column into integers?
# ##### * What information can you extract out of job descriptions?
# ##### * How can you remove the numbers from the company name?
# ##### * How can you create some new features? (e.g. state column from the location column)

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\K A L K I D A N\OneDrive\Desktop\projects\data cleaning\glassdoor_jobs.CSV")

# %%
df.info
# Out:
# <bound method DataFrame.info of                                              Job Title  \
# 0                                       Data Scientist
# 1                                       Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 995                                     Data Scientist
# 996  Analytic Consultant 4 - Branch Banking Reporti...
# 997                                     Data Scientist
# 998                                     Data Scientist
# 999                              Clinical Data Analyst
#
#                   Salary Estimate  \
# 0      $77K-$92K (Glassdoor Est.)
# 1      $77K-$92K (Glassdoor Est.)
# 2      $77K-$92K (Glassdoor Est.)
# 3      $77K-$92K (Glassdoor Est.)
# 4      $77K-$92K (Glassdoor Est.)
# ..                            ...
# 995  $105K-$138K (Glassdoor Est.)
# 996  $105K-$138K (Glassdoor Est.)
# 997  $105K-$138K (Glassdoor Est.)
# 998  $105K-$138K (Glassdoor Est.)
# 999  $105K-$138K (Glassdoor Est.)
#
#                                        Job Description  Rating  \
# 0    Data Scientist\nAffinity Solutions / Marketing...     2.9
# 1    Secure our Nation, Ignite your Future\n\nSumma...     4.1
# 2    By clicking the Apply button, I understand tha...     3.7
# 3    Join Our Growing Team\nA career with A Place f...     3.0
# 4    We are looking for Data Scientists who are int...     3.7
# ..                                                 ...     ...
# 995  • Be one of the first to join our rapidly grow...     5.0
# 996  Job Description\n\nImportant Note: During the ...     3.6
# 997  THE COMPANY\n\nFannie Mae provides reliable, l...     3.6
# 998  Ready to write the best chapter of your career...     3.9
# 999  About Us:\n\nNYSTEC is a non-profit technology...     3.8
#
#                 Company Name           Location          Headquarters  \
# 0    Affinity Solutions\n2.9       New York, NY          New York, NY
# 1               ManTech\n4.1      Chantilly, VA           Herndon, VA
# 2                Takeda\n3.7      Cambridge, MA          OSAKA, Japan
# 3       A Place for Mom\n3.0  Overland Park, KS          New York, NY
# 4               GovTech\n3.7  San Francisco, CA  Singapore, Singapore
# ..                       ...                ...                   ...
# 995        Shelf Engine\n5.0        Seattle, WA           Seattle, WA
# 996         Wells Fargo\n3.6         Dallas, TX     San Francisco, CA
# 997          Fannie Mae\n3.6     Washington, DC        Washington, DC
# 998  XSELL Technologies\n3.9        Chicago, IL           Chicago, IL
# 999              NYSTEC\n3.8       New York, NY              Rome, NY
#
#                         Size  Founded        Type of ownership  \
# 0        51 to 200 employees     1998        Company - Private
# 1    5001 to 10000 employees     1968         Company - Public
# 2           10000+ employees     1781         Company - Public
# 3      501 to 1000 employees     2000        Company - Private
# 4     1001 to 5000 employees     2016               Government
# ..                       ...      ...                      ...
# 995        1 to 50 employees       -1        Company - Private
# 996         10000+ employees     1852         Company - Public
# 997  5001 to 10000 employees     1938         Company - Public
# 998      51 to 200 employees     2014        Company - Private
# 999      51 to 200 employees     1996  Non-profit Organisation
#
#                                     Industry                     Sector  \
# 0                    Advertising & Marketing          Business Services
# 1                     Research & Development          Business Services
# 2                  Biotech & Pharmaceuticals  Biotech & Pharmaceuticals
# 3            Healthcare Services & Hospitals                 Healthcare
# 4                        Government Agencies                 Government
# ..                                       ...                        ...
# 995                                       -1                         -1
# 996               Banks & Building Societies                    Finance
# 997    Investment Banking & Asset Management                    Finance
# 998  Enterprise Software & Network Solutions     Information Technology
# 999                               Consulting          Business Services
#
#                         Revenue  \
# 0      Unknown / Non-Applicable
# 1    ₹100 to ₹500 billion (INR)
# 2           ₹500+ billion (INR)
# 3      Unknown / Non-Applicable
# 4      Unknown / Non-Applicable
# ..                          ...
# 995    Unknown / Non-Applicable
# 996         ₹500+ billion (INR)
# 997         ₹500+ billion (INR)
# 998    Unknown / Non-Applicable
# 999      ₹1 to ₹5 billion (INR)
#
#                                            Competitors
# 0                 Commerce Signals, Cardlytics, Yodlee
# 1                                                   -1
# 2                             Novartis, Baxter, Pfizer
# 3    Enlivant, Sunrise Senior Living, Brookdale Sen...
# 4                                                   -1
# ..                                                 ...
# 995                                                 -1
# 996                                                 -1
# 997                                        Freddie Mac
# 998                                                 -1
# 999                          KPMG, Accenture, Deloitte
#
# [1000 rows x 14 columns]>

# %%
# Remove the '$' sign, 'K' for thousands, and extract the lower and upper ranges
df['Salary Estimate'] = df['Salary Estimate'].str.replace(r'[^0-9\-]', '', regex=True)

# Split the salary range and calculate the average salary
df['Salary Estimate'] = df['Salary Estimate'].str.split('-').apply(lambda x: (int(x[0]) + int(x[1])) / 2 if len(x) == 2 else int(x[0]))

# Convert to integer
df['Salary Estimate'] = df['Salary Estimate'].astype(int)

# %%
df['Salary Estimate']
# Out:
# 0       84
# 1       84
# 2       84
# 3       84
# 4       84
#       ...
# 995    121
# 996    121
# 997    121
# 998    121
# 999    121
# Name: Salary Estimate, Length: 1000, dtype: int32

# %%
import re

# Extract skills from job descriptions (example with a few keywords)
df['skills'] = df['Job Description'].apply(lambda x: ', '.join(re.findall(r'\b(Python|SQL|Machine Learning|Data Analysis|R)\b', x, flags=re.IGNORECASE)))

# Example: Extracting years of experience from job descriptions
df['years_of_experience'] = df['Job Description'].apply(lambda x: re.findall(r'\d+ years? of experience', x))

# Example: Extracting if the education level is mentioned (Bachelor or Master)
df['education_required'] = df['Job Description'].apply(lambda x: 'Bachelor' if 'bachelor' in x.lower() else ('Master' if 'master' in x.lower() else 'None'))

# %%
# Remove numbers from the company name
df['Company Name'] = df['Company Name'].replace({r'\d+': ''}, regex=True).str.strip()

# %%
df['Company Name']
# Out:
# 0      Affinity Solutions\n.
# 1                 ManTech\n.
# 2                  Takeda\n.
# 3         A Place for Mom\n.
# 4                 GovTech\n.
#                ...
# 995          Shelf Engine\n.
# 996           Wells Fargo\n.
# 997            Fannie Mae\n.
# 998    XSELL Technologies\n.
# 999                NYSTEC\n.
# Name: Company Name, Length: 1000, dtype: object

# %%
df.head()
# Out:
#         Job Title  Salary Estimate  \
# 0  Data Scientist               84
# 1  Data Scientist               84
# 2  Data Scientist               84
# 3  Data Scientist               84
# 4  Data Scientist               84
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nAffinity Solutions / Marketing...     2.9
# 1  Secure our Nation, Ignite your Future\n\nSumma...     4.1
# 2  By clicking the Apply button, I understand tha...     3.7
# 3  Join Our Growing Team\nA career with A Place f...     3.0
# 4  We are looking for Data Scientists who are int...     3.7
#
#             Company Name           Location          Headquarters  \
# 0  Affinity Solutions\n.       New York, NY          New York, NY
# 1             ManTech\n.      Chantilly, VA           Herndon, VA
# 2              Takeda\n.      Cambridge, MA          OSAKA, Japan
# 3     A Place for Mom\n.  Overland Park, KS          New York, NY
# 4             GovTech\n.  San Francisco, CA  Singapore, Singapore
#
#                       Size  Founded  Type of ownership  \
# 0      51 to 200 employees     1998  Company - Private
# 1  5001 to 10000 employees     1968   Company - Public
# 2         10000+ employees     1781   Company - Public
# 3    501 to 1000 employees     2000  Company - Private
# 4   1001 to 5000 employees     2016         Government
#
#                           Industry                     Sector  \
# 0          Advertising & Marketing          Business Services
# 1           Research & Development          Business Services
# 2        Biotech & Pharmaceuticals  Biotech & Pharmaceuticals
# 3  Healthcare Services & Hospitals                 Healthcare
# 4              Government Agencies                 Government
#
#                       Revenue  \
# 0    Unknown / Non-Applicable
# 1  ₹100 to ₹500 billion (INR)
# 2         ₹500+ billion (INR)
# 3    Unknown / Non-Applicable
# 4    Unknown / Non-Applicable
#
#                                          Competitors  \
# 0               Commerce Signals, Cardlytics, Yodlee
# 1                                                 -1
# 2                           Novartis, Baxter, Pfizer
# 3  Enlivant, Sunrise Senior Living, Brookdale Sen...
# 4                                                 -1
#
#                                               skills years_of_experience  \
# 0  machine learning, machine learning, Python, R,...                  []
# 1  data analysis, data analysis, machine learning...                  []
# 2  Machine Learning, machine learning, Data Analy...                  []
# 3  machine learning, machine learning, data analy...                  []
# 4                        machine learning, R, Python                  []
#
#   education_required
# 0               None
# 1               None
# 2             Master
# 3           Bachelor
# 4           Bachelor

# %%
# First, let's check if the Location column has the expected format
df['Location'].head()

# Split the 'Location' column into 'City' and 'State' carefully
df[['City', 'State']] = df['Location'].str.split(',', expand=True, n=1)

# Clean up extra spaces and handle missing values
df['City'] = df['City'].str.strip()
df['State'] = df['State'].str.strip()

# Check for any rows with missing values (in case some locations do not follow the 'City, State' format)
df[['City', 'State']].isnull().sum()

# For rows where the State is missing, assign the Country (if available) to the State
df['State'].fillna(df['Location'].apply(lambda x: x.split(',')[-1] if ',' in x else ''), inplace=True)

# Display the updated columns
print(df[['Location', 'City', 'State']].head())
# Out:
#             Location           City State
# 0       New York, NY       New York    NY
# 1      Chantilly, VA      Chantilly    VA
# 2      Cambridge, MA      Cambridge    MA
# 3  Overland Park, KS  Overland Park    KS
# 4  San Francisco, CA  San Francisco    CA
# C:\Users\K A L K I D A N\AppData\Local\Temp\ipykernel_10508\3972090298.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['State'].fillna(df['Location'].apply(lambda x: x.split(',')[-1] if ',' in x else ''), inplace=True)

# %%
df.info
# Out:
# <bound method DataFrame.info of                                              Job Title  Salary Estimate  \
# 0                                       Data Scientist               84
# 1                                       Data Scientist               84
# 2                                       Data Scientist               84
# 3                                       Data Scientist               84
# 4                                       Data Scientist               84
# ..                                                 ...              ...
# 995                                     Data Scientist              121
# 996  Analytic Consultant 4 - Branch Banking Reporti...              121
# 997                                     Data Scientist              121
# 998                                     Data Scientist              121
# 999                              Clinical Data Analyst              121
#
#                                        Job Description  Rating  \
# 0    Data Scientist\nAffinity Solutions / Marketing...     2.9
# 1    Secure our Nation, Ignite your Future\n\nSumma...     4.1
# 2    By clicking the Apply button, I understand tha...     3.7
# 3    Join Our Growing Team\nA career with A Place f...     3.0
# 4    We are looking for Data Scientists who are int...     3.7
# ..                                                 ...     ...
# 995  • Be one of the first to join our rapidly grow...     5.0
# 996  Job Description\n\nImportant Note: During the ...     3.6
# 997  THE COMPANY\n\nFannie Mae provides reliable, l...     3.6
# 998  Ready to write the best chapter of your career...     3.9
# 999  About Us:\n\nNYSTEC is a non-profit technology...     3.8
#
#               Company Name           Location          Headquarters  \
# 0    Affinity Solutions\n.       New York, NY          New York, NY
# 1               ManTech\n.      Chantilly, VA           Herndon, VA
# 2                Takeda\n.      Cambridge, MA          OSAKA, Japan
# 3       A Place for Mom\n.  Overland Park, KS          New York, NY
# 4               GovTech\n.  San Francisco, CA  Singapore, Singapore
# ..                     ...                ...                   ...
# 995        Shelf Engine\n.        Seattle, WA           Seattle, WA
# 996         Wells Fargo\n.         Dallas, TX     San Francisco, CA
# 997          Fannie Mae\n.     Washington, DC        Washington, DC
# 998  XSELL Technologies\n.        Chicago, IL           Chicago, IL
# 999              NYSTEC\n.       New York, NY              Rome, NY
#
#                         Size  Founded        Type of ownership  \
# 0        51 to 200 employees     1998        Company - Private
# 1    5001 to 10000 employees     1968         Company - Public
# 2           10000+ employees     1781         Company - Public
# 3      501 to 1000 employees     2000        Company - Private
# 4     1001 to 5000 employees     2016               Government
# ..                       ...      ...                      ...
# 995        1 to 50 employees       -1        Company - Private
# 996         10000+ employees     1852         Company - Public
# 997  5001 to 10000 employees     1938         Company - Public
# 998      51 to 200 employees     2014        Company - Private
# 999      51 to 200 employees     1996  Non-profit Organisation
#
#                                     Industry                     Sector  \
# 0                    Advertising & Marketing          Business Services
# 1                     Research & Development          Business Services
# 2                  Biotech & Pharmaceuticals  Biotech & Pharmaceuticals
# 3            Healthcare Services & Hospitals                 Healthcare
# 4                        Government Agencies                 Government
# ..                                       ...                        ...
# 995                                       -1                         -1
# 996               Banks & Building Societies                    Finance
# 997    Investment Banking & Asset Management                    Finance
# 998  Enterprise Software & Network Solutions     Information Technology
# 999                               Consulting          Business Services
#
#                         Revenue  \
# 0      Unknown / Non-Applicable
# 1    ₹100 to ₹500 billion (INR)
# 2           ₹500+ billion (INR)
# 3      Unknown / Non-Applicable
# 4      Unknown / Non-Applicable
# ..                          ...
# 995    Unknown / Non-Applicable
# 996         ₹500+ billion (INR)
# 997         ₹500+ billion (INR)
# 998    Unknown / Non-Applicable
# 999      ₹1 to ₹5 billion (INR)
#
#                                            Competitors  \
# 0                 Commerce Signals, Cardlytics, Yodlee
# 1                                                   -1
# 2                             Novartis, Baxter, Pfizer
# 3    Enlivant, Sunrise Senior Living, Brookdale Sen...
# 4                                                   -1
# ..                                                 ...
# 995                                                 -1
# 996                                                 -1
# 997                                        Freddie Mac
# 998                                                 -1
# 999                          KPMG, Accenture, Deloitte
#
#                                                 skills years_of_experience  \
# 0    machine learning, machine learning, Python, R,...                  []
# 1    data analysis, data analysis, machine learning...                  []
# 2    Machine Learning, machine learning, Data Analy...                  []
# 3    machine learning, machine learning, data analy...                  []
# 4                          machine learning, R, Python                  []
# ..                                                 ...                 ...
# 995                   SQL, Python, R, machine learning                  []
# 996                       SQL, SQL, SQL, SQL, SQL, SQL                  []
# 997                   machine learning, SQL, R, Python                  []
# 998  machine learning, machine learning, Python, Ma...                  []
# 999                                        SQL, Python                  []
#
#     education_required           City State
# 0                 None       New York    NY
# 1                 None      Chantilly    VA
# 2               Master      Cambridge    MA
# 3             Bachelor  Overland Park    KS
# 4             Bachelor  San Francisco    CA
# ..                 ...            ...   ...
# 995             Master        Seattle    WA
# 996             Master         Dallas    TX
# 997           Bachelor     Washington    DC
# 998               None        Chicago    IL
# 999           Bachelor       New York    NY
#
# [1000 rows x 19 columns]>

# %%
# To clean the company names by removing unwanted characters like \n, we can use the str.replace() method.
df['Company Name'] = df['Company Name'].str.replace(r'\n|\.','', regex=True)

# %%
df['Company Name']
# Out:
# 0      Affinity Solutions
# 1                 ManTech
# 2                  Takeda
# 3         A Place for Mom
# 4                 GovTech
#               ...
# 995          Shelf Engine
# 996           Wells Fargo
# 997            Fannie Mae
# 998    XSELL Technologies
# 999                NYSTEC
# Name: Company Name, Length: 1000, dtype: object

# %%
# create a new column for Skills by identifying the common skills mentioned:
df['Skills'] = df['Job Description'].str.extract(r'(machine learning|Python|R|SQL|data analysis)', expand=False)

# %%
df['Skills']
# Out:
# 0      machine learning
# 1         data analysis
# 2      machine learning
# 3                     R
# 4      machine learning
#              ...
# 995                 SQL
# 996                   R
# 997                   R
# 998                   R
# 999                   R
# Name: Skills, Length: 1000, dtype: object

# %%
#  Create a new column that groups companies into Small, Medium, or Large based on the number of employees.
df['Company Size Category'] = df['Size'].apply(lambda x: 'Small' if '1 to 50' in x else ('Medium' if '51 to 200' in x or '201 to 1000' in x else 'Large'))

# %%
df['Company Size Category']
# Out:
# 0      Medium
# 1       Large
# 2       Large
# 3       Large
# 4       Small
#         ...
# 995     Small
# 996     Large
# 997     Large
# 998    Medium
# 999    Medium
# Name: Company Size Category, Length: 1000, dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of                                              Job Title  Salary Estimate  \
# 0                                       Data Scientist               84
# 1                                       Data Scientist               84
# 2                                       Data Scientist               84
# 3                                       Data Scientist               84
# 4                                       Data Scientist               84
# ..                                                 ...              ...
# 995                                     Data Scientist              121
# 996  Analytic Consultant 4 - Branch Banking Reporti...              121
# 997                                     Data Scientist              121
# 998                                     Data Scientist              121
# 999                              Clinical Data Analyst              121
#
#                                        Job Description  Rating  \
# 0    Data Scientist\nAffinity Solutions / Marketing...     2.9
# 1    Secure our Nation, Ignite your Future\n\nSumma...     4.1
# 2    By clicking the Apply button, I understand tha...     3.7
# 3    Join Our Growing Team\nA career with A Place f...     3.0
# 4    We are looking for Data Scientists who are int...     3.7
# ..                                                 ...     ...
# 995  • Be one of the first to join our rapidly grow...     5.0
# 996  Job Description\n\nImportant Note: During the ...     3.6
# 997  THE COMPANY\n\nFannie Mae provides reliable, l...     3.6
# 998  Ready to write the best chapter of your career...     3.9
# 999  About Us:\n\nNYSTEC is a non-profit technology...     3.8
#
#            Company Name           Location          Headquarters  \
# 0    Affinity Solutions       New York, NY          New York, NY
# 1               ManTech      Chantilly, VA           Herndon, VA
# 2                Takeda      Cambridge, MA          OSAKA, Japan
# 3       A Place for Mom  Overland Park, KS          New York, NY
# 4               GovTech  San Francisco, CA  Singapore, Singapore
# ..                  ...                ...                   ...
# 995        Shelf Engine        Seattle, WA           Seattle, WA
# 996         Wells Fargo         Dallas, TX     San Francisco, CA
# 997          Fannie Mae     Washington, DC        Washington, DC
# 998  XSELL Technologies        Chicago, IL           Chicago, IL
# 999              NYSTEC       New York, NY              Rome, NY
#
#                         Size  Founded        Type of ownership  ...  \
# 0        51 to 200 employees     1998        Company - Private  ...
# 1    5001 to 10000 employees     1968         Company - Public  ...
# 2           10000+ employees     1781         Company - Public  ...
# 3      501 to 1000 employees     2000        Company - Private  ...
# 4     1001 to 5000 employees     2016               Government  ...
# ..                       ...      ...                      ...  ...
# 995        1 to 50 employees       -1        Company - Private  ...
# 996         10000+ employees     1852         Company - Public  ...
# 997  5001 to 10000 employees     1938         Company - Public  ...
# 998      51 to 200 employees     2014        Company - Private  ...
# 999      51 to 200 employees     1996  Non-profit Organisation  ...
#
#                         Sector                     Revenue  \
# 0            Business Services    Unknown / Non-Applicable
# 1            Business Services  ₹100 to ₹500 billion (INR)
# 2    Biotech & Pharmaceuticals         ₹500+ billion (INR)
# 3                   Healthcare    Unknown / Non-Applicable
# 4                   Government    Unknown / Non-Applicable
# ..                         ...                         ...
# 995                         -1    Unknown / Non-Applicable
# 996                    Finance         ₹500+ billion (INR)
# 997                    Finance         ₹500+ billion (INR)
# 998     Information Technology    Unknown / Non-Applicable
# 999          Business Services      ₹1 to ₹5 billion (INR)
#
#                                            Competitors  \
# 0                 Commerce Signals, Cardlytics, Yodlee
# 1                                                   -1
# 2                             Novartis, Baxter, Pfizer
# 3    Enlivant, Sunrise Senior Living, Brookdale Sen...
# 4                                                   -1
# ..                                                 ...
# 995                                                 -1
# 996                                                 -1
# 997                                        Freddie Mac
# 998                                                 -1
# 999                          KPMG, Accenture, Deloitte
#
#                                                 skills years_of_experience  \
# 0    machine learning, machine learning, Python, R,...                  []
# 1    data analysis, data analysis, machine learning...                  []
# 2    Machine Learning, machine learning, Data Analy...                  []
# 3    machine learning, machine learning, data analy...                  []
# 4                          machine learning, R, Python                  []
# ..                                                 ...                 ...
# 995                   SQL, Python, R, machine learning                  []
# 996                       SQL, SQL, SQL, SQL, SQL, SQL                  []
# 997                   machine learning, SQL, R, Python                  []
# 998  machine learning, machine learning, Python, Ma...                  []
# 999                                        SQL, Python                  []
#
#     education_required           City State            Skills  \
# 0                 None       New York    NY  machine learning
# 1                 None      Chantilly    VA     data analysis
# 2               Master      Cambridge    MA  machine learning
# 3             Bachelor  Overland Park    KS                 R
# 4             Bachelor  San Francisco    CA  machine learning
# ..                 ...            ...   ...               ...
# 995             Master        Seattle    WA               SQL
# 996             Master         Dallas    TX                 R
# 997           Bachelor     Washington    DC                 R
# 998               None        Chicago    IL                 R
# 999           Bachelor       New York    NY                 R
#
#     Company Size Category
# 0                  Medium
# 1                   Large
# 2                   Large
# 3                   Large
# 4                   Small
# ..                    ...
# 995                 Small
# 996                 Large
# 997                 Large
# 998                Medium
# 999                Medium
#
# [1000 rows x 21 columns]>
